# %% [markdown]
# # Data Input and Output

# %%
import pandas as pd

# %%
pd.read_csv('epl201920.csv')
# Out:
#      Round             Date               Team 1   FT                Team 2
# 0        1   Fri Aug 9 2019         Liverpool FC  4-1       Norwich City FC
# 1        1  Sat Aug 10 2019   West Ham United FC  0-5    Manchester City FC
# 2        1  Sat Aug 10 2019           Burnley FC  3-0        Southampton FC
# 3        1  Sat Aug 10 2019      AFC Bournemouth  1-1   Sheffield United FC
# 4        1  Sat Aug 10 2019    Crystal Palace FC  0-0            Everton FC
# ..     ...              ...                  ...  ...                   ...
# 375     38  Sun Jul 26 2020    Leicester City FC  0-2  Manchester United FC
# 376     38  Sun Jul 26 2020   Manchester City FC  5-0       Norwich City FC
# 377     38  Sun Jul 26 2020  Newcastle United FC  1-3          Liverpool FC
# 378     38  Sun Jul 26 2020       Southampton FC  3-1   Sheffield United FC
# 379     38  Sun Jul 26 2020   West Ham United FC  1-1        Aston Villa FC
#
# [380 rows x 5 columns]

# %% [markdown]
# pd.read_ , press tab to see the options

# %%
df = pd.read_csv('epl201920.csv')

# %%
df
# Out:
#      Round             Date               Team 1   FT                Team 2
# 0        1   Fri Aug 9 2019         Liverpool FC  4-1       Norwich City FC
# 1        1  Sat Aug 10 2019   West Ham United FC  0-5    Manchester City FC
# 2        1  Sat Aug 10 2019           Burnley FC  3-0        Southampton FC
# 3        1  Sat Aug 10 2019      AFC Bournemouth  1-1   Sheffield United FC
# 4        1  Sat Aug 10 2019    Crystal Palace FC  0-0            Everton FC
# ..     ...              ...                  ...  ...                   ...
# 375     38  Sun Jul 26 2020    Leicester City FC  0-2  Manchester United FC
# 376     38  Sun Jul 26 2020   Manchester City FC  5-0       Norwich City FC
# 377     38  Sun Jul 26 2020  Newcastle United FC  1-3          Liverpool FC
# 378     38  Sun Jul 26 2020       Southampton FC  3-1   Sheffield United FC
# 379     38  Sun Jul 26 2020   West Ham United FC  1-1        Aston Villa FC
#
# [380 rows x 5 columns]

# %%
df.to_csv('output',index=False)

# %%
pd.read_csv('output')
# Out:
#      Round             Date               Team 1   FT                Team 2
# 0        1   Fri Aug 9 2019         Liverpool FC  4-1       Norwich City FC
# 1        1  Sat Aug 10 2019   West Ham United FC  0-5    Manchester City FC
# 2        1  Sat Aug 10 2019           Burnley FC  3-0        Southampton FC
# 3        1  Sat Aug 10 2019      AFC Bournemouth  1-1   Sheffield United FC
# 4        1  Sat Aug 10 2019    Crystal Palace FC  0-0            Everton FC
# ..     ...              ...                  ...  ...                   ...
# 375     38  Sun Jul 26 2020    Leicester City FC  0-2  Manchester United FC
# 376     38  Sun Jul 26 2020   Manchester City FC  5-0       Norwich City FC
# 377     38  Sun Jul 26 2020  Newcastle United FC  1-3          Liverpool FC
# 378     38  Sun Jul 26 2020       Southampton FC  3-1   Sheffield United FC
# 379     38  Sun Jul 26 2020   West Ham United FC  1-1        Aston Villa FC
#
# [380 rows x 5 columns]

# %% [markdown]
# Exports and saves a copy named 'output' to the folder

# %%
data = pd.read_html('https://www.premierleague.com/tables')

# %%
data[0].head()
# Out:
#                                        Position  Pos  \
# 0                            1  Previous Position  1
# 1  Arsenal  Recent Result - Sunday 16 October 202...
# 2                            2  Previous Position  2
# 3  Manchester City  Recent Result - Sunday 16 Oct...
# 4                            3  Previous Position  3
#
#                                                 Club  \
# 0                                       Arsenal  ARS
# 1  Arsenal  Recent Result - Sunday 16 October 202...
# 2                               Manchester City  MCI
# 3  Manchester City  Recent Result - Sunday 16 Oct...
# 4                             Tottenham Hotspur  TOT
#
#                                           Played  Pl  \
# 0                                                 10
# 1  Arsenal  Recent Result - Sunday 16 October 202...
# 2                                                 10
# 3  Manchester City  Recent Result - Sunday 16 Oct...
# ...

# %%
type(data)
# Out:
# list
